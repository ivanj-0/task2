# %% [markdown]
# <a href="https://colab.research.google.com/github/ivanj-0/task2copy/blob/main/Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ivanj-0/task2.git > /dev/null 2>&1
# %cd /content/task2
# !pip install -r requirements.txt > /dev/null 2>&1
# Out:
# /content/task2

# %%
# !python defence_gan.py 2>/dev/null | grep -E "Using device: cuda|Attack LPIPS|Defense LPIPS"
# Out:
# Using device: cuda
# Attack LPIPS: 0.432908
# Defense LPIPS: 0.022881

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

comparison_img_path = "defense_comparison_combined.png"
lpips_plot_path = "defense_lpips_history.png"

print("\nComparison Image (Original / Attacked / Defended):")
img1 = Image.open(comparison_img_path)
plt.figure(figsize=(5, 3))
plt.imshow(np.asarray(img1))
plt.axis('off')
plt.show()

print("\nLPIPS History Plot:")
img2 = mpimg.imread(lpips_plot_path)
plt.figure(figsize=(6, 4))
plt.imshow(img2)
plt.axis('off')
plt.show()
# Out:
# Comparison Image (Original / Attacked / Defended):
# LPIPS History Plot:
